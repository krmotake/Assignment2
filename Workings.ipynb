# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Richard M**
# Actuary

# %% [markdown]
# *I am interested in Data Science because is the course of the future. I wanna stay relevant and not easily substituted by a "Machine".*

# %% [markdown]
# ### Print "Hello world!"

# %%
str = "Hello world!"
print(str)
# Out:
# Hello world!

# %% [markdown]
# |Name| |Surname| |Age| |Date Joined Company| |Basic Salary|
# |----| |-------| |---| |--------| |-----|
# |Kanye| |West| |45| |1977| |2 billion|
# |Kim| | kard| |41| |1980| |1.8 billion|
# |Elon| |Musk| |51| |1971| |300 billion|
#
# ~~This is included~~
#
# > It is what it is.
